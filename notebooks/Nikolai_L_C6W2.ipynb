# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
#import seaborn
import datetime
import scipy
from scipy.stats import binned_statistic_2d
from bokeh.io import output_file, show, output_notebook
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool, Quad,
    DataRange1d, Plot, LinearAxis, Grid, Line, Patches
)
from bokeh.models import GeoJSONDataSource
from bokeh.palettes import RdYlBu11, Plasma, Viridis, Category10
from bokeh.models import LogColorMapper, LinearColorMapper
# %matplotlib inline

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="40b1e17c-9007-4c73-8244-9f26688ae2b4">Loading BokehJS ...</span>
#     </div>

# %%
#%%time
#Читаем данные за май 2016
dates = ['tpep_pickup_datetime', 'tpep_dropoff_datetime']

cols_to_use = ['tpep_pickup_datetime', 
               'tpep_dropoff_datetime',
               'passenger_count',
               'trip_distance',
               'pickup_longitude', 
               'pickup_latitude',
               'dropoff_longitude',
               'dropoff_latitude']

data = pd.read_csv('TaxiData/yellow_tripdata_2016-05.csv', delimiter=',',
                   usecols=cols_to_use, 
                   parse_dates=dates)

# %%
data.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0           2016-05-01   2016-05-01 00:17:31                1           3.60
# 1           2016-05-01   2016-05-01 00:07:31                1           1.68
# 2           2016-05-01   2016-05-01 00:07:01                6           1.09
# 3           2016-05-01   2016-05-01 00:19:47                1           4.21
# 4           2016-05-01   2016-05-01 00:06:39                1           0.56
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        -73.985901        40.768040         -73.983986         40.730099
# 1        -73.991577        40.744751         -73.975700         40.765469
# 2        -73.993073        40.741573         -73.980995         40.744633
# 3        -73.991943        40.684601         -74.002258         40.733002
# 4        -74.005280        40.740192         -73.997498         40.737564

# %%
#На всякий случай проверяем пустые значения
print data.isnull().values.any()

#Задаем границы 
long_min = -74.25559
long_max = -73.70001 
lat_min = 40.49612
lat_max = 40.91553
# Out:
# False

# %%
#Фильтруем данные по границам, длительности, кол-ву пассажиров, длине поездки.

zero_delta = datetime.timedelta(seconds=0)

data = data[((data.tpep_dropoff_datetime - data.tpep_pickup_datetime) > zero_delta) 
                     & (data.passenger_count > 0) 
                     & (data.trip_distance > 0)
                     & (long_min <= data.pickup_longitude)
                     & (data.pickup_longitude <= long_max)
                     & (lat_min <= data.pickup_latitude)
                     & (data.pickup_latitude <= lat_max)
             ]

# %%
#%%time
#Получаем регионы для каждой поездки (в виде индексов бинов по двум осям)
stat, x_edge , y_edge, binnumber = binned_statistic_2d(data.pickup_longitude, 
                                                       data.pickup_latitude, 
                                                       None,
                                                       statistic='count',
                                                       bins=50, 
                                                       range=[[long_min, long_max], [lat_min, lat_max]],
                                                       expand_binnumbers=True,)

# %%
#%%time
#Записываем регионы для каждой позедки в виде одномерного индекса
region_arr = np.array([(x-1) * 50 + y for x, y in zip(*binnumber)])
data.loc[:,('region')] = region_arr

# %%
#Окргугляем время начала вниз до ближайшего часа 
data.loc[:,('tpep_pickup_datetime')] = data.tpep_pickup_datetime.dt.floor('h')
data.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0           2016-05-01   2016-05-01 00:17:31                1           3.60
# 1           2016-05-01   2016-05-01 00:07:31                1           1.68
# 2           2016-05-01   2016-05-01 00:07:01                6           1.09
# 3           2016-05-01   2016-05-01 00:19:47                1           4.21
# 4           2016-05-01   2016-05-01 00:06:39                1           0.56
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.985901        40.768040         -73.983986         40.730099
# 1        -73.991577        40.744751         -73.975700         40.765469
# 2        -73.993073        40.741573         -73.980995         40.744633
# 3        -73.991943        40.684601         -74.002258         40.733002
# 4        -74.005280        40.740192         -73.997498         40.737564
#
#    region
# 0    1233
# 1    1180
# 2    1180
# 3    1173
# 4    1130

# %%
#%%time
#Получаем аггрегированные данные (время, регион, кол-во поездок) - пока без учета пар время-регион где не было поездок.
agg = data.groupby([data.tpep_pickup_datetime, data.region]).size().reset_index(name='count')

# %%
agg.head()
# Out:
#   tpep_pickup_datetime  region  count
# 0           2016-05-01    1015      1
# 1           2016-05-01    1017      1
# 2           2016-05-01    1029      3
# 3           2016-05-01    1030      1
# 4           2016-05-01    1033      4

# %%
#Теперь дополним фрейм строками для тех пар время-регион для которых не было поездок.

#Для этого возьмем все возможные времена начала поздки
times = agg.groupby(['tpep_pickup_datetime']).size().index.values
print len(times)
#Создадим фрейм из всех кобинаций регионов и часов
all_regions = range(1,2501)

placeholder = pd.MultiIndex.from_product([times, all_regions], names=['tpep_pickup_datetime','region']).to_frame()
placeholder.reset_index(drop=True, inplace=True)
# Out:
# 744

# %%
#Джоиним два фрейма и после заполням нулями ячейки для пар в которых не было поездок
res = pd.merge(agg, placeholder, 'right', on=['tpep_pickup_datetime', 'region'])
res = res.fillna(0)

# %%
#Считаем кол-во поездок из каждой ячейки за весь месяц
region_grp = res.groupby(['region']).sum().reset_index()

#Считаем кол-во ячеек из которых не было совершено ни одной поездки
region_grp[region_grp['count'] == 0].shape[0]
# Out:
# 1283

# %%
#Empire State Building
esb_lat = 40.748351
esb_long = -73.985621

regions = pd.read_csv('TaxiData/regions.csv', delimiter=';')
regions.head()
# Out:
#    region      west       east      south      north
# 0       1 -74.25559 -74.244478  40.496120  40.504508
# 1       2 -74.25559 -74.244478  40.504508  40.512896
# 2       3 -74.25559 -74.244478  40.512896  40.521285
# 3       4 -74.25559 -74.244478  40.521285  40.529673
# 4       5 -74.25559 -74.244478  40.529673  40.538061

# %%
#Формируем координаты четырех вершин для прямоугольников представляющих каждую область
regions['xs'] = regions.apply(lambda df: [df['west'], df['west'], df['east'], df['east']], axis=1)
regions['ys'] = regions.apply(lambda df: [df['north'], df['south'], df['south'], df['north']], axis=1)

#Джойним фрейм с прямоугольниками и фрейм с общим кол-вом поездок в области за месяц
regions = pd.merge(regions, region_grp, 'left', on=['region'])
regions
# Out:
#       region       west       east      south      north  \
# 0          1 -74.255590 -74.244478  40.496120  40.504508
# 1          2 -74.255590 -74.244478  40.504508  40.512896
# 2          3 -74.255590 -74.244478  40.512896  40.521285
# 3          4 -74.255590 -74.244478  40.521285  40.529673
# 2495    2496 -73.711122 -73.700010  40.873589  40.881977
# 2496    2497 -73.711122 -73.700010  40.881977  40.890365
# 2497    2498 -73.711122 -73.700010  40.890365  40.898754
# 2498    2499 -73.711122 -73.700010  40.898754  40.907142
# 2499    2500 -73.711122 -73.700010  40.907142  40.915530
#
#                                                     xs  \
# 0     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 1     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 2     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 3     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 4     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 5     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 6     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 7     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 8     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 9     [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 10    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 11    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 12    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 13    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 14    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 15    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 16    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 17    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 18    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 19    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 20    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 21    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 22    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 23    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 24    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 25    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 26    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 27    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 28    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 29    [-74.25559, -74.25559, -74.2444784, -74.2444784]
# ...                                                ...
# 2470  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2471  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2472  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2473  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2474  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2475  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2476  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2477  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2478  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2479  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# 2480  [-73.7111216, -73.7111216, -73.70001, -73.70001]
# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk"

source = ColumnDataSource(
    data=dict(
        lat=[esb_lat],
        lon=[esb_long],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="black", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

output_file("gmap_esb.html")

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9b464fbe-ec84-4aaa-9544-ee19de846fc7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("9b464fbe-ec84-4aaa-9544-ee19de846fc7");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9b464fbe-ec84-4aaa-9544-ee19de846fc7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9b464fbe-ec84-4aaa-9544-ee19de846fc7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"88fcf32e-d55c-4600-9865-c27887566275":{"roots":{"references":[{"attributes":{"callback":null},"id":"5c16c44a-c2a1-4038-a71d-a99712cc32c6","type":"DataRange1d"},{"attributes":{"plot":null,"text":"New York Empire State Building Point"},"id":"4d12bc5d-a240-484f-9611-9a017e384453","type":"Title"},{"attributes":{},"id":"15ed8250-53d8-4756-95ed-0f6044124ede","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"black"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"836fcb20-45f6-4a68-a873-55c574123986","type":"Circle"},{"attributes":{"callback":null},"id":"b5b1acc2-0db1-4a27-9bd0-926450a82d30","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.748351],"lon":[-73.985621]}},"id":"a4b6d2ba-8a21-443a-9416-d6d3a8884d2a","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto"},"id":"272879ef-23c8-4ba4-bdc8-8024fe3004cc","type":"Toolbar"},{"attributes":{},"id":"0a0dbb98-4ef9-4e80-97cd-13985f9ac486","type":"LinearScale"},{"attributes":{"source":{"id":"a4b6d2ba-8a21-443a-9416-d6d3a8884d2a","type":"ColumnDataSource"}},"id":"61d6502a-496b-45b0-ae24-cbf80ac042e5","type":"CDSView"},{"attributes":{"lat":40.748351,"lng":-73.985621,"zoom":10},"id":"9dc4392c-0307-4a08-bad4-e21c6de6f89a","type":"GMapOptions"},{"attributes":{"api_key":"AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk","map_options":{"id":"9dc4392c-0307-4a08-bad4-e21c6de6f89a","type":"GMapOptions"},"renderers":[{"id":"3b3cb8a3-06c8-4573-a8ff-06bf94dd60ff","type":"GlyphRenderer"}],"title":{"id":"4d12bc5d-a240-484f-9611-9a017e384453","type":"Title"},"toolbar":{"id":"272879ef-23c8-4ba4-bdc8-8024fe3004cc","type":"Toolbar"},"x_range":{"id":"5c16c44a-c2a1-4038-a71d-a99712cc32c6","type":"DataRange1d"},"x_scale":{"id":"15ed8250-53d8-4756-95ed-0f6044124ede","type":"LinearScale"},"y_range":{"id":"b5b1acc2-0db1-4a27-9bd0-926450a82d30","type":"DataRange1d"},"y_scale":{"id":"0a0dbb98-4ef9-4e80-97cd-13985f9ac486","type":"LinearScale"}},"id":"2d9805d5-3636-44fe-8804-aff2c54dff4e","type":"GMapPlot"},{"attributes":{"data_source":{"id":"a4b6d2ba-8a21-443a-9416-d6d3a8884d2a","type":"ColumnDataSource"},"glyph":{"id":"836fcb20-45f6-4a68-a873-55c574123986","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"61d6502a-496b-45b0-ae24-cbf80ac042e5","type":"CDSView"}},"id":"3b3cb8a3-06c8-4573-a8ff-06bf94dd60ff","type":"GlyphRenderer"}],"root_ids":["2d9805d5-3636-44fe-8804-aff2c54dff4e"]},"title":"Bokeh Application","version":"0.12.7"}};
#             var render_items = [{"docid":"88fcf32e-d55c-4600-9865-c27887566275","elementid":"9b464fbe-ec84-4aaa-9544-ee19de846fc7","modelid":"2d9805d5-3636-44fe-8804-aff2c54dff4e"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((root.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i].call(root, root.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!root._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         root._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("9b464fbe-ec84-4aaa-9544-ee19de846fc7")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (root._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(window));
# </script>

# %%
#heatmap для общего кол-ва поездок за месяц
esb_lat = 40.748351
esb_long = -73.985621
map_options = GMapOptions(lat=esb_lat, lng=esb_long, map_type="roadmap", zoom=10)

plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
plot.title.text = "New York Total Trips Heatmap"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk"

source = ColumnDataSource(dict(
        xs = regions['xs'],
        ys = regions['ys'],
        cs = regions['count']
    )
)

color_mapper = LogColorMapper(palette = RdYlBu11)

glyph = Patches(xs="xs", ys="ys", fill_color={'field': 'cs', 'transform': color_mapper}, fill_alpha=0.5)
plot.add_glyph(source, glyph)

#output_file("gmap_heat_sum.html")
# Out:
# GlyphRenderer(id='f6dab4b8-185b-41a5-ab01-59210ec06be8', ...)

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3aad0ae-7352-4457-83e1-ee564411f618"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a3aad0ae-7352-4457-83e1-ee564411f618");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3aad0ae-7352-4457-83e1-ee564411f618");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3aad0ae-7352-4457-83e1-ee564411f618' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b2e99ad-df7d-459d-be76-e7ba33a509fa":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["cs","xs","ys"],"data":{"cs":{"__ndarray__":"...","dtype":"float64","shape":[2500]},"xs":[[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444784,-74.2444784],[-74.25559,-74.25559,-74.2444
plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
plot.title.text = "New York Statue of Liberty Point"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk"

source = ColumnDataSource(
    data=dict(
        lat=[lib_lat],
        lon=[lib_long],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="black", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
#output_file("gmap_liberty.html")

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7d547203-4b59-4ba0-8c44-04d79347120c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7d547203-4b59-4ba0-8c44-04d79347120c");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7d547203-4b59-4ba0-8c44-04d79347120c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7d547203-4b59-4ba0-8c44-04d79347120c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fe89bfdf-23a7-41a3-a1ea-9cdfd95e4493":{"roots":{"references":[{"attributes":{},"id":"a14364f8-f39a-40e4-b3db-4f8107414e4a","type":"LinearScale"},{"attributes":{"callback":null,"overlay":{"id":"19afad92-9c02-491c-b07f-581b3f1749d9","type":"BoxAnnotation"}},"id":"77825edd-6e76-473a-9d7b-0af5e3a17ade","type":"BoxSelectTool"},{"attributes":{},"id":"ecc5ffbf-9c3d-40d4-909d-2a2eddb3d2dd","type":"PanTool"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":[40.689435],"lon":[-74.044919]}},"id":"3c573877-7104-47cc-be23-2bdafcb58102","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"19afad92-9c02-491c-b07f-581b3f1749d9","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ecc5ffbf-9c3d-40d4-909d-2a2eddb3d2dd","type":"PanTool"},{"id":"aed179e4-0c6a-42e3-8b30-426053d95ea1","type":"WheelZoomTool"},{"id":"77825edd-6e76-473a-9d7b-0af5e3a17ade","type":"BoxSelectTool"}]},"id":"cfefd547-5332-455f-bf40-3259b4f8f94e","type":"Toolbar"},{"attributes":{"api_key":"AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk","map_options":{"id":"5f30c546-d500-460f-9736-d2fab210f2eb","type":"GMapOptions"},"renderers":[{"id":"46140f4c-8810-4237-b1ea-e88f33c8d55d","type":"GlyphRenderer"},{"id":"19afad92-9c02-491c-b07f-581b3f1749d9","type":"BoxAnnotation"}],"title":{"id":"593fc374-1500-40ab-83ad-639f03b82605","type":"Title"},"toolbar":{"id":"cfefd547-5332-455f-bf40-3259b4f8f94e","type":"Toolbar"},"x_range":{"id":"b3ff317f-bc0a-4e7e-bcd9-d7b9ffa030a8","type":"DataRange1d"},"x_scale":{"id":"a14364f8-f39a-40e4-b3db-4f8107414e4a","type":"LinearScale"},"y_range":{"id":"3111e125-8685-4f8f-b22a-c34ed55a3e58","type":"DataRange1d"},"y_scale":{"id":"eb8710c0-3994-4abc-a13f-184a6cc39ac2","type":"LinearScale"}},"id":"d1d09a0d-1007-45b0-b2d8-d6a0a2dfa980","type":"GMapPlot"},{"attributes":{},"id":"aed179e4-0c6a-42e3-8b30-426053d95ea1","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"3111e125-8685-4f8f-b22a-c34ed55a3e58","type":"DataRange1d"},{"attributes":{"source":{"id":"3c573877-7104-47cc-be23-2bdafcb58102","type":"ColumnDataSource"}},"id":"18289bb4-edf5-4c0e-9581-d93dd182c827","type":"CDSView"},{"attributes":{"plot":null,"text":"New York Statue of Liberty Point"},"id":"593fc374-1500-40ab-83ad-639f03b82605","type":"Title"},{"attributes":{"callback":null},"id":"b3ff317f-bc0a-4e7e-bcd9-d7b9ffa030a8","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"black"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"a8b85517-5511-4171-bac2-122d50477cf1","type":"Circle"},{"attributes":{"data_source":{"id":"3c573877-7104-47cc-be23-2bdafcb58102","type":"ColumnDataSource"},"glyph":{"id":"a8b85517-5511-4171-bac2-122d50477cf1","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"18289bb4-edf5-4c0e-9581-d93dd182c827","type":"CDSView"}},"id":"46140f4c-8810-4237-b1ea-e88f33c8d55d","type":"GlyphRenderer"},{"attributes":{},"id":"eb8710c0-3994-4abc-a13f-184a6cc39ac2","type":"LinearScale"},{"attributes":{"lat":40.689435,"lng":-74.044919,"zoom":10},"id":"5f30c546-d500-460f-9736-d2fab210f2eb","type":"GMapOptions"}],"root_ids":["d1d09a0d-1007-45b0-b2d8-d6a0a2dfa980"]},"title":"Bokeh Application","version":"0.12.7"}};
#             var render_items = [{"docid":"fe89bfdf-23a7-41a3-a1ea-9cdfd95e4493","elementid":"7d547203-4b59-4ba0-8c44-04d79347120c","modelid":"d1d09a0d-1007-45b0-b2d8-d6a0a2dfa980"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((root.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i].call(root, root.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!root._bokeh_failed_load) {

# %%
#Считаем среднее кол-во поездок из каждой ячейки в час
region_grp_mean = res.groupby(['region']).mean().reset_index().rename(columns={'count':'avg'})
region_grp_mean.head()
# Out:
#    region  avg
# 0       1  0.0
# 1       2  0.0
# 2       3  0.0
# 3       4  0.0
# 4       5  0.0

# %%
#Джойним фрейм с прямоугольниками и фрейм со средним кол-вом поездок за час из области 
regions = pd.merge(regions, region_grp_mean, 'left', on=['region'])
regions.head()
# Out:
#    region      west       east      south      north  \
# 0       1 -74.25559 -74.244478  40.496120  40.504508
# 1       2 -74.25559 -74.244478  40.504508  40.512896
# 2       3 -74.25559 -74.244478  40.512896  40.521285
# 3       4 -74.25559 -74.244478  40.521285  40.529673
# 4       5 -74.25559 -74.244478  40.529673  40.538061
#
#                                                  xs  \
# 0  [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 1  [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 2  [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 3  [-74.25559, -74.25559, -74.2444784, -74.2444784]
# 4  [-74.25559, -74.25559, -74.2444784, -74.2444784]
#
#                                                  ys  count  avg
# 0      [40.5045082, 40.49612, 40.49612, 40.5045082]    0.0  0.0
# 1  [40.5128964, 40.5045082, 40.5045082, 40.5128964]    0.0  0.0
# 2  [40.5212846, 40.5128964, 40.5128964, 40.5212846]    0.0  0.0
# 3  [40.5296728, 40.5212846, 40.5212846, 40.5296728]    0.0  0.0
# 4    [40.538061, 40.5296728, 40.5296728, 40.538061]    0.0  0.0

# %%
#Отфильтруем ячейки, из которых в мае совершается в среднем меньше 5 поездок в час. 
regions_ge5 = regions[regions['avg'] >= 5]
regions_ge5.shape[0]
# Out:
# 102

# %%
#heatmap для среднего кол-ва поездок в час
lib_lat = 40.689435
lib_long = -74.044919

#lib_lat = 40.689238
#lib_long = -74.044415

map_options = GMapOptions(lat=lib_lat, lng=lib_long, map_type="roadmap", zoom=10)

plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
plot.title.text = "New York"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk"

source = ColumnDataSource(dict(
        xs = regions_ge5['xs'],
        ys = regions_ge5['ys'],
        cs = regions_ge5['avg']
    )
)

color_mapper = LogColorMapper(palette = Viridis[256])

glyph = Patches(xs="xs", ys="ys", fill_color={'field': 'cs', 'transform': color_mapper}, fill_alpha=0.5)
plot.add_glyph(source, glyph)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
#output_file("gmap_heat_avg.html")

show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd873e40-fd7b-4715-9392-c34366bdb73d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("cd873e40-fd7b-4715-9392-c34366bdb73d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd873e40-fd7b-4715-9392-c34366bdb73d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd873e40-fd7b-4715-9392-c34366bdb73d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"64f9a01e-61f4-440a-8ac5-a57d1c1022a6":{"roots":{"references":[{"attributes":{"api_key":"AIzaSyCVvDzBM9DBR1CeRFY-WqLniq1odSdzUCk","map_options":{"id":"cc1e8903-f1ae-4368-bea2-a01b776aaa09","type":"GMapOptions"},"renderers":[{"id":"a2a736ba-4968-44f8-b3d5-c74a045a2143","type":"GlyphRenderer"},{"id":"2fb58fc7-ef5c-4174-adea-4bbbb337d961","type":"BoxAnnotation"}],"title":{"id":"d395ced5-a24e-4cbf-8b4a-f6447c3b0dbd","type":"Title"},"toolbar":{"id":"1a230ddb-2b00-4fb4-a9ea-e419f44dbd79","type":"Toolbar"},"x_range":{"id":"0f2dc2e0-ab41-43d8-bd49-c73414228199","type":"DataRange1d"},"x_scale":{"id":"89eae63f-534e-4dba-a7f1-2f20b78a0e37","type":"LinearScale"},"y_range":{"id":"0b04bac6-5584-429c-83d9-35b47bd82f7e","type":"DataRange1d"},"y_scale":{"id":"2486ff6f-0947-406b-b0a6-45cd4fd769aa","type":"LinearScale"}},"id":"8480deff-bc99-4415-802e-f9b6dd89750d","type":"GMapPlot"},{"attributes":{"data_source":{"id":"ba86ca7a-859c-440f-a69d-4208aa610ffd","type":"ColumnDataSource"},"glyph":{"id":"00267f67-ab1e-411f-ad7e-cabcee27bdd5","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"view":{"id":"07f59e76-7d93-4d7a-9ebf-b26b9a404261","type":"CDSView"}},"id":"a2a736ba-4968-44f8-b3d5-c74a045a2143","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"020f4a8f-4107-42cb-a4c7-65c0a3baa23c","type":"PanTool"},{"id":"ec860511-dbaa-413c-9842-ef188dfb2cec","type":"WheelZoomTool"},{"id":"929cf5e9-494f-4c52-97d0-2c8d382e139d","type":"BoxSelectTool"}]},"id":"1a230ddb-2b00-4fb4-a9ea-e419f44dbd79","type":"Toolbar"},{"attributes":{},"id":"020f4a8f-4107-42cb-a4c7-65c0a3baa23c","type":"PanTool"},{"attributes":{"palette":["#440154","#440255","#440357","#450558","#45065A","#45085B","#46095C","#460B5E","#460C5F","#460E61","#470F62","#471163","#471265","#471466","#471567","#471669","#47186A","#48196B","#481A6C","#481C6E","#481D6F","#481E70","#482071","#482172","#482273","#482374","#472575","#472676","#472777","#472878","#472A79","#472B7A","#472C7B","#462D7C","#462F7C","#46307D","#46317E","#45327F","#45347F","#453580","#453681","#443781","#443982","#433A83","#433B83","#433C84","#423D84","#423E85","#424085","#414186","#414286","#404387","#404487","#3F4587","#3